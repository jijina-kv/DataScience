# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/shaji/Documents/Phyton Assignment/New-Pandas-Assignment-2/housing.csv')
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df[df['waterfront']>0]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 49      822039084  20150311T000000  1350000         3       2.50         2753
# 230    8096000060  20150413T000000   655000         2       1.75         1450
# 246    2025069065  20140929T000000  2400000         4       2.50         3650
# 264    2123039032  20141027T000000   369900         1       0.75          760
# 300    3225069065  20140624T000000  3075000         4       5.00         4550
# ...           ...              ...      ...       ...        ...          ...
# 19984  2025069140  20150317T000000  1898000         3       2.50         2830
# 20325   518500480  20140811T000000  3000000         3       3.50         4410
# 20767  8043700105  20150417T000000  2300000         4       4.00         4360
# 21201   518500460  20141008T000000  2230000         3       3.50         3760
# 21576  9253900271  20150107T000000  3567000         5       4.50         4850
#
# ...

# %%
df[df['price']==df.max()['price']].zipcode
# Out:
# 7252    98102
# Name: zipcode, dtype: int64

# %%
#Q4
print(df[pd.isnull(df['sqft_above'])])
print(df[pd.isnull(df['date'])])
print(df[pd.isnull(df['price'])])
print(df[pd.isnull(df['bedrooms'])])
print(df[pd.isnull(df['bathrooms'])])
print(df[pd.isnull(df['sqft_living'])])
print(df[pd.isnull(df['sqft_lot'])])
print(df[pd.isnull(df['floors'])])
print(df[pd.isnull(df['waterfront'])])
print(df[pd.isnull(df['view'])])
print(df[pd.isnull(df['condition'])])
print(df[pd.isnull(df['grade'])])
print(df[pd.isnull(df['sqft_above'])])
print(df[pd.isnull(df['sqft_basement'])])
print(df[pd.isnull(df['yr_built'])])
print(df[pd.isnull(df['yr_renovated'])])
print(df[pd.isnull(df['zipcode'])])
print(df[pd.isnull(df['lat'])])
print(df[pd.isnull(df['long'])])
print(df[pd.isnull(df['sqft_living15'])])
print(df[pd.isnull(df['sqft_lot15'])])
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]
# Empty DataFrame
# ...

# %%
df[df['grade']==10].grade.count()
# Out:
# 1134

# %%
#Q5
df[df.id==9126100861].waterfront
# Out:
# 400    0
# Name: waterfront, dtype: int64

# %%
#Q6
df[df.view==3].id.count()
# Out:
# 510

# %%
#Q7
df['price'].min()
# Out:
# 75000

# %%
#Q8
df[df['price']==df['price'].min()].zipcode
# Out:
# 1149    98022
# Name: zipcode, dtype: int64

# %%
#Q9
df[df['sqft_living']==df['sqft_living'].max()].zipcode
# Out:
# 12777    98053
# Name: zipcode, dtype: int64

# %%
#Q10
df[df['price']==df['price'].max()].yr_built
# Out:
# 7252    1910
# Name: yr_built, dtype: int64

# %%
df[(df['sqft_lot']<400)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
#Q16
def IncreaseGrade(sqft_lot):
    if sqft_lot>400:
        return 2
    elif  sqft_lot>0 & sqft_lot<=400:
        return 1
    else:
        return 0
df['grade']=df['grade']+df['sqft_lot'].apply(IncreaseGrade)

# %%
df.duplicated(subset=['id','zipcode','grade'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
df.iloc[3:6, 6:10]
# Out:
#    sqft_lot  floors  waterfront  view
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0
# 5    101930     1.0           0     0

# %%
df1 = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])
df1
# Out:
#      A   B
# r1  34  12
# r2  78  67
# r3  54  43

# %%
df1.loc['r2':'r3']
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %%
df['date'] = pd.to_datetime(df['date'],dayfirst = True,errors='coerce')
df['date'] = df['date'].dt.strftime('%m/%d/%Y')
# show the types 
df
# Out:
#                id        date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900         3       1.00         1180
# 1      6414100192  12/09/2014  538000         3       2.25         2570
# 2      5631500400  02/25/2015  180000         2       1.00          770
# 3      2487200875  12/09/2014  604000         4       3.00         1960
# 4      1954400510  02/18/2015  510000         3       2.00         1680
# ...           ...         ...     ...       ...        ...          ...
# 21608   263000018  05/21/2014  360000         3       2.50         1530
# 21609  6600060120  02/23/2015  400000         4       2.50         2310
# 21610  1523300141  06/23/2014  402101         2       0.75         1020
# 21611   291310100  01/16/2015  400000         3       2.50         1600
# 21612  1523300157  10/15/2014  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df2=df[(df['yr_built']>1980)&(df['bedrooms']>2)&(df['floors']>2)]
df2
# Out:
#                id        date   price  bedrooms  bathrooms  sqft_living  \
# 63     9528102996  12/07/2014  549000         3       1.75         1540
# 116    3362400431  06/26/2014  518500         3       3.50         1590
# 134    2767602356  01/26/2015  675000         4       3.50         2140
# 139    2767603505  05/07/2014  519950         3       2.25         1170
# 406    7821200390  08/06/2014  450000         3       2.00         1290
# ...           ...         ...     ...       ...        ...          ...
# 21587  6632300207  03/05/2015  385000         3       2.50         1520
# 21592  1931300412  04/16/2015  475000         3       2.25         1190
# 21601  5100403806  04/07/2015  467000         3       2.50         1425
# 21604  9834201367  01/26/2015  429000         3       2.00         1490
# 21608   263000018  05/21/2014  360000         3       2.50         1530
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
#Q23
sample_list = [['Carl', 22],
['Martha', 25],
['Calvin', 12],
['Stuart', 15]
]
df3=pd.DataFrame(sample_list,columns=['Name','Age'])
df3
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
#Q24
sample_dict = {'Cristiano': ['Ronaldo','Man U', 801],
'Lionel': ['Messi','PSG', 758],
'Luis': ['Suarez','Atletico Madrid', 509],
'Robert': ['Lewandowski','Bayern Munich', 527],
'Zlatan': ['Ibrahimovic','AC Milan',553]
}
df4=pd.concat([pd.DataFrame(sample_dict.keys(),columns=['First Name']),pd.DataFrame(sample_dict.values(),columns=['lastname','club','goals'])],join='inner',axis=1)
df4
# Out:
#   First Name     lastname             club  goals
# 0  Cristiano      Ronaldo            Man U    801
# 1     Lionel        Messi              PSG    758
# 2       Luis       Suarez  Atletico Madrid    509
# 3     Robert  Lewandowski    Bayern Munich    527
# 4     Zlatan  Ibrahimovic         AC Milan    553

# %%
sample_tuple = ([1, 'one', 3],
[2, 'two', 3],
[3, 'Three', 5],
[4, 'Four', 4],
[5, 'Five', 4])
df5=pd.DataFrame(sample_tuple,columns=['no','Number_text','Number'],index=[1,2,3,4,5])
df5=df5.drop(columns=["no"])
df5
# Out:
#   Number_text  Number
# 1         one       3
# 2         two       3
# 3       Three       5
# 4        Four       4
# 5        Five       4

# %%
df6=df.sort_values(by="price",ascending=False)
print(df6)
df7=df.sort_values(by="price",ascending=True)
print(df7)
# Out:
#                id        date    price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020  10/13/2014  7700000         6       8.00        12050
# 3914   9808700762  06/11/2014  7062500         5       4.50        10040
# 9254   9208900037  09/19/2014  6885000         6       7.75         9890
# 4411   2470100110  08/04/2014  5570000         5       5.75         9200
# 1448   8907500070  04/13/2015  5350000         5       5.00         8000
# ...           ...         ...      ...       ...        ...          ...
# 8274   3883800011  11/05/2014    82000         3       1.00          860
# 16198  3028200080  03/24/2015    81000         2       1.00          730
# 465    8658300340  05/23/2014    80000         1       0.75          430
# 15293    40000362  05/06/2014    78000         2       1.00          780
# 1149   3421079032  02/17/2015    75000         1       0.00          670
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.mean()
# Out:
# C:\Users\shaji\AppData\Local\Temp/ipykernel_1576/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788391e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\shaji\AppData\Local\Temp/ipykernel_1576/3249793613.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# id               2.876566e+09
# price            3.671272e+05
# bedrooms         9.300618e-01
# bathrooms        7.701632e-01
# sqft_living      9.184409e+02
# sqft_lot         4.142051e+04
# floors           5.399889e-01
# waterfront       8.651720e-02
# view             7.663176e-01
# condition        6.507430e-01
# grade            1.175459e+00
# sqft_above       8.280910e+02
# sqft_basement    4.425750e+02
# yr_built         2.937341e+01
# yr_renovated     4.016792e+02
# zipcode          5.350503e+01
# lat              1.385637e-01
# long             1.408283e-01
# sqft_living15    6.853913e+02
# sqft_lot15       2.730418e+04
# dtype: float64

# %%
df[25:36]
# Out:
#             id        date   price  bedrooms  bathrooms  sqft_living  \
# 25  1202000200  11/03/2014  233000         3       2.00         1710
# 26  1794500383  06/26/2014  937000         3       1.75         2450
# 27  3303700376  12/01/2014  667000         3       1.00         1400
# 28  5101402488  06/24/2014  438000         3       1.75         1520
# 29  1873100390  03/02/2015  719000         4       2.50         2570
# 30  8562750320  11/10/2014  580500         3       2.50         2320
# 31  2426039314  12/01/2014  280000         2       1.50         1190
# 32   461000390  06/24/2014  687500         4       1.75         2330
# 33  7589200193  11/10/2014  535000         3       1.00         1090
# 34  7955080270  12/03/2014  322500         4       2.75         2060
# 35  9547205180  06/13/2014  696000         3       2.50         2300
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df[(df.lat==47.6168) &(df.long==-122.045)]
# Out:
#            id        date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4  1954400510  02/18/2015  510000         3        2.0         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [1 rows x 21 columns]

# %%
df['Floor Area']=df["sqft_living"]+df["sqft_lot"]+df["sqft_above"]+df["sqft_basement"]
df8=df.drop(columns=["id","bedrooms","bathrooms","sqft_living","sqft_lot","floors","waterfront","view","condition","grade","sqft_above",
"sqft_basement","yr_built","yr_renovated","zipcode","lat","long","sqft_living15","sqft_lot15"])
df8
# Out:
#              date   price  Floor Area
# 0      10/13/2014  221900        8010
# 1      12/09/2014  538000       12382
# 2      02/25/2015  180000       11540
# 3      12/09/2014  604000        8920
# 4      02/18/2015  510000       11440
# ...           ...     ...         ...
# 21608  05/21/2014  360000        4191
# 21609  02/23/2015  400000       10433
# 21610  06/23/2014  402101        3390
# 21611  01/16/2015  400000        5588
# 21612  10/15/2014  325000        3116
#
# [21613 rows x 3 columns]

# %%
A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], columns=['Name', 'Age'])
B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], columns=['Name', 'Age'])
print(A.merge(B,on='Name',how='left'))
print(A.merge(B,on='Name',how='outer'))
print(A.merge(B,on='Name',how='inner'))
print(A.merge(B,on='Name',how='right'))
# Out:
#      Name  Age_x  Age_y
# 0    Carl     22    NaN
# 1  Martha     25   34.0
# 2  Calvin     12    NaN
# 3  Stuart     15    NaN
#      Name  Age_x  Age_y
# 0    Carl   22.0    NaN
# 1  Martha   25.0   34.0
# 2  Calvin   12.0    NaN
# 3  Stuart   15.0    NaN
# 4  Melvin    NaN   25.0
# 5   Lewis    NaN   32.0
# 6     Leo    NaN   25.0
#      Name  Age_x  Age_y
# 0  Martha     25     34
#      Name  Age_x  Age_y
# 0  Melvin    NaN     25
# 1  Martha   25.0     34
# 2   Lewis    NaN     32
# 3     Leo    NaN     25

# %%
 df["sqft_living"].corr(df["sqft_above"])
# Out:
# 0.8765965986813177
